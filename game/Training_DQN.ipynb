# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, sys
PATH = "/content/drive/MyDrive/quoridor/game"

os.chdir(PATH)
sys.path.append(PATH+"/AI")

# %%
from dqn_trainerV2 import DQNTrainerV2

dqn_trainer = DQNTrainerV2()

# %%
dqn_trainer.train_dqn()
# Out:
# ## Training 0/10 ##
# Creation du dataset : jeu
# Processus effectué à 95.5%
# Proportion d'actions illégales : 96%
# Entrainement du réseau REWARDS
# Pas assez de données au cours de cette passe.
# Entrainement du réseau RULES
# Loss : 0.6463165084520975
# Nombre de parties déjà jouées : 6
#
# ## Training 1/10 ##
# Creation du dataset : jeu
# Processus effectué à 81.5%
# Proportion d'actions illégales : 32%
# Entrainement du réseau REWARDS
# Loss : 0.07087987413009007
# Entrainement du réseau RULES
# Loss : 0.4263586865531074
# Nombre de parties déjà jouées : 14
#
# ## Training 2/10 ##
# Creation du dataset : jeu
# Processus effectué à 99.7%
# Proportion d'actions illégales : 17%
# Entrainement du réseau REWARDS
# Loss : 0.0950136836618185
# Entrainement du réseau RULES
# Loss : 0.6782325260779437
# Nombre de parties déjà jouées : 26
#
# ## Training 3/10 ##
# Creation du dataset : jeu
# Processus effectué à 95.7%
# Proportion d'actions illégales : 19%
# ...
